# %%
pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.5 🚀 Python-3.9.13 torch-2.3.0 CPU (Cortex-A76)
# Setup complete ✅ (4 CPUs, 7.9 GB RAM, 24.9/28.7 GB disk)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
model = YOLO('yolov8n.yaml')

# %%
results = model.train(data='coco8.yaml', epochs=100, imgsz=640, task='detect')

# %%
validation_results = model.val(data='coco8.yaml',
                               imgsz=640,
                               batch=16,
                               conf=0.25,
                               iou=0.6,
                               device='0')

# %%
# Load a pretrained YOLOv8n model
model = YOLO('yolov8n.pt')

# Define path to the image file
source = 'path/to/image.jpg'

# Run inference on the source
results = model(source)  # list of Results objects
