# %%
pip install ultralytics
# Out:
# ...
#
# ...
#      ------------------------------------ 756.9/756.9 KB 782.7 kB/s eta 0:00:00
# ...
#      -------------------------------------- 11.6/11.6 MB 777.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 152.8/152.8 KB 380.0 kB/s eta 0:00:00
# ...
#      -------------------------------------- 62.6/62.6 KB 556.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.2/1.2 MB 744.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 7.7/7.7 MB 821.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.2/46.2 MB 2.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.3/78.3 KB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 294.9/294.9 KB 3.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 2.5/2.5 MB 8.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 38.6/38.6 MB 7.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 159.7/159.7 MB 3.2 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.15  Python-3.9.13 torch-2.3.0+cpu CPU (Intel Core(TM) i5-9300H 2.40GHz)
# Setup complete  (8 CPUs, 15.8 GB RAM, 231.0/730.1 GB disk)

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.0+cpu

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
model = YOLO('yolov8x.pt')

# %%
model = YOLO(r'C:\Users\Giancarlos\Documents\modeloyolo\yolov8x.pt')

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.0+cpu

# %%
model = YOLO('C:/Users/Giancarlos/Documents/modeloyolo/yolov8x.pt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 model = YOLO('C:/Users/Giancarlos/Documents/modeloyolo/yolov8x.pt')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\ultralytics\engine\model.py:152, in Model.__init__(self, model, task, verbose)
#     150     self._new(model, task=task, verbose=verbose)
#     151 else:
# --> 152     self._load(model, task=task)
# ...

# %%
model = YOLO(r'C:\Users\Giancarlos\Documents\modeloyolo\yolov8x.pt')

# %%
results = model.train(data='/media/pi/Maxell8/Modelo/Seminario1/fruitsYolov8/configvsc.yaml', epochs=100, imgsz=640, task='detect')

# %%
model = YOLO('path/to/best.pt')

# %%
validation_results = model.val(data='/media/pi/Maxell8/Modelo/Seminario1/fruitsYolov8/configvsc.yaml',
                               imgsz=640,
                               batch=16,
                               conf=0.25,
                               iou=0.6,
                               device='0',
                               split= 'test')
